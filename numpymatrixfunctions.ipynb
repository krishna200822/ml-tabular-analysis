# %%
# import libiary
import numpy as np
import time

# %%
# test and compare performance of numpy vs plain python loop -vector addtion
n=10000000
a =[1]*n
b=[2]*n
start = time.time()

c=[0]*n
for i in range (n):
    c[i]=a[i]+b[i]
end = time.time()
print(end-start)
# Out:
# 1.5090315341949463

# %%
#numpy implementation
s =time.time()

a_np=np.arange(n) # numpy array
b_np= np.arange(n)
c_np=a_np+ b_np
e =time.time()
print(e-s)
# Out:
# 0.11437082290649414

# %%
# create two matrix using numpy array
A = np.array([[1,2,3],[0,1,0],[0,0,1]]) #matric-A
B= np.array([[0,1,0],[1,0,0],[1,2,1]])# matrix B

# %%
A.shape
# Out:
# (3, 3)

# %%
A
# Out:
# array([[1, 2, 3],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
# sum of two matrix
print(A+B)
# Out:
# [[1 3 3]
#  [1 1 0]
#  [1 2 2]]

# %%
# MULTIPIUCATION OF TWO MATIX
print(A@B)
print(np.matmul(A,B))
# Out:
# [[5 7 3]
#  [1 0 0]
#  [1 2 1]]
# [[5 7 3]
#  [1 0 0]
#  [1 2 1]]

# %%
# find transpose of matrix
print(A.T)
print(np.transpose(A))
# Out:
# [[1 0 0]
#  [2 1 0]
#  [3 0 1]]
# [[1 0 0]
#  [2 1 0]
#  [3 0 1]]

# %%
# find dt of matrix
print(np.linalg.det(A))
# Out:
# 1.0

# %%
# inverse of matrix
print(np.linalg.inv(B))
# Out:
# [[ 0.  1.  0.]
#  [ 1.  0.  0.]
#  [-2. -1.  1.]]

# %%
# trace
print(np.linalg.trace(A))
# Out:
# 3

# %%
#find rank of matrix
print(np.linalg.matrix_rank(A))
# Out:
# 3

# %%
# eign value and eign vector
print(np.linalg.eig(A))
# Out:
# EigResult(eigenvalues=array([1., 1., 1.]), eigenvectors=array([[ 1.00000000e+00, -1.00000000e+00, -1.00000000e+00],
#        [ 0.00000000e+00,  1.11022302e-16,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  7.40148683e-17]]))
