# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 3.0 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.9 MB 3.3 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.9 MB 3.6 MB/s eta 0:00:03
#    ------------ --------------------------- 3.1/9.9 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.9 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.9 MB 3.2 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.9 MB 3.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.9 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.9 MB 3.0 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.9 MB 3.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 3.1 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.2'

# %%
# data frame
# create data frmae
df=pd.DataFrame([11,22,33],columns=['col_name'])
print(df)
print(type(df))
# Out:
#    col_name
# 0        11
# 1        22
# 2        33
# <class 'pandas.DataFrame'>

# %%
data ={
    'Name': ["krishna","sarthak","ramraj","shivraj"],
    'Age': [16,17,18,19],
    'Salary': [19000,70000,50000,30000]


}

# %%
df =pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       Name  Age  Salary
# 0  krishna   16   19000
# 1  sarthak   17   70000
# 2   ramraj   18   50000
# 3  shivraj   19   30000
# <class 'pandas.DataFrame'>

# %%
# basic dtat frmae under standing
df.head(2) # top two rows
# Out:
#       Name  Age  Salary
# 0  krishna   16   19000
# 1  sarthak   17   70000

# %%
df.tail(2)#last two rows
# Out:
#       Name  Age  Salary
# 2   ramraj   18   50000
# 3  shivraj   19   30000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df1=df.rename(columns={'Salary':'Monthly_Salary'})# change salary column name to monthly_salary
print(df1)
# Out:
#       Name  Age  Monthly_Salary
# 0  krishna   16           19000
# 1  sarthak   17           70000
# 2   ramraj   18           50000
# 3  shivraj   19           30000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe()# all statiscal data
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   17.500000  42250.000000
# std     1.290994  22514.809941
# min    16.000000  19000.000000
# 25%    16.750000  27250.000000
# 50%    17.500000  40000.000000
# 75%    18.250000  55000.000000
# max    19.000000  70000.000000

# %%
# save and load csv files

# %%
df.to_csv('test_data.csv',index =False)# save csv file without index

# %%
load_df= pd.read_csv('test_data.csv')# load csv file from system
load_df
# Out:
#       Name  Age  Salary
# 0  krishna   16   19000
# 1  sarthak   17   70000
# 2   ramraj   18   50000
# 3  shivraj   19   30000

# %%
# rows column selection

# %%
df[['Name']]# return that column
# Out:
#       Name
# 0  krishna
# 1  sarthak
# 2   ramraj
# 3  shivraj

# %%
df.loc[df.Name=='krishna']# LOC INDEX NAME BASED
# Out:
#       Name  Age  Salary
# 0  krishna   16   19000

# %%
df.loc[(df.Name=='krishna')&(df.Salary>=10000)]# check both condtion
# Out:
#       Name  Age  Salary
# 0  krishna   16   19000

# %%
#df.iloc[0]
df.iloc[0:2]
# Out:
#       Name  Age  Salary
# 0  krishna   16   19000
# 1  sarthak   17   70000

# %%
df[df['Age']>18]
# Out:
#       Name  Age  Salary
# 3  shivraj   19   30000

# %%
df.where(df['Age']>=18,other = 'Not Eligible')
# Out:
#            Name           Age        Salary
# 0  Not Eligible  Not Eligible  Not Eligible
# 1  Not Eligible  Not Eligible  Not Eligible
# 2        ramraj            18         50000
# 3       shivraj            19         30000

# %%
# rows and columns opreation

# %%
# add a column
df['Team']=['CEO','HR','CTO' ,'DA']
df
# Out:
#       Name  Age  Salary    bonus Team
# 0  krishna   16   19000   3800.0  CEO
# 1  sarthak   17   70000  14000.0   HR
# 2   ramraj   18   50000  10000.0  CTO
# 3  shivraj   19   30000   6000.0   DA

# %%
df ['bonus']=df['Salary']*0.2
df
# Out:
#       Name  Age  Salary    bonus Team
# 0  krishna   16   90000  18000.0  CEO
# 1  sarthak   17   70000  14000.0   HR
# 2   ramraj   18   50000  10000.0  CTO
# 3  shivraj   19   30000   6000.0   DA
# 4      ABC   21    2100    420.0  200

# %%
df.loc[len(df)]=['ABC',21,2100,'IT',200] # add row
df
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
# update value
df.loc[0,'Salary'] = 90000
df
# Out:
#       Name  Age  Salary    bonus Team
# 0  krishna   16   90000   3800.0  CEO
# 1  sarthak   17   70000  14000.0   HR
# 2   ramraj   18   50000  10000.0  CTO
# 3  shivraj   19   30000   6000.0   DA
# 4      ABC   21    2100       IT  200

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
# delete value
df =df .drop(df[df.Name=='ABC'].index)

# %%
# delte column
df.drop('bonus',axis=1)
# Out:
#       Name  Age  Salary Team
# 0  krishna   16   90000  CEO
# 1  sarthak   17   70000   HR
# 2   ramraj   18   50000  CTO
# 3  shivraj   19   30000   DA

# %%
# sprt value
df.sort_values('Salary')
# Out:
#       Name  Age  Salary    bonus Team
# 3  shivraj   19   30000   6000.0   DA
# 2   ramraj   18   50000  10000.0  CTO
# 1  sarthak   17   70000  14000.0   HR
# 0  krishna   16   90000  18000.0  CEO

# %%
# workinbg with date value
df["DOJ"] = ["2024-01-01","2024-02-15", "2024-03-10","2024-04-20"]
df
# Out:
#       Name  Age  Salary    bonus Team         DOJ
# 0  krishna   16   90000  18000.0  CEO  2024-01-01
# 1  sarthak   17   70000  14000.0   HR  2024-02-15
# 2   ramraj   18   50000  10000.0  CTO  2024-03-10
# 3  shivraj   19   30000   6000.0   DA  2024-04-20

# %%
#convert it into date data type 
df['DOJ']=pd.to_datetime(df['DOJ'])

# %%
# if format is not same
df1=df

# %%
df1["DOJ2"] = ["16-10-2009","30-11-2018", "11-12-2009","15-11-2009"]
df1
# Out:
#       Name  Age  Salary    bonus Team        DOJ        DOJ2
# 0  krishna   16   90000  18000.0  CEO 2024-01-01  16-10-2009
# 1  sarthak   17   70000  14000.0   HR 2024-02-15  30-11-2018
# 2   ramraj   18   50000  10000.0  CTO 2024-03-10  11-12-2009
# 3  shivraj   19   30000   6000.0   DA 2024-04-20  15-11-2009

# %%
df1['DOJ2']=pd.to_datetime(df1['DOJ2'],format='%d-%m-%Y')# we have to give instsuction abvout format

# %%
df= df.drop('DOJ2',axis=1)

# %%
df['DOJ'].dt.year
df["DOJ"].dt.month
df["DOJ"].dt.day
df["DOJ"].dt.day_name()
df["DOJ"].dt.month_name()
# Out:
# 0     January
# 1    February
# 2       March
# 3       April
# Name: DOJ, dtype: str

# %%
df ['DOJ']+ pd.Timedelta(days=90)# add thsese  dates to date
# Out:
# 0   2024-03-31
# 1   2024-05-15
# 2   2024-06-08
# 3   2024-07-19
# Name: DOJ, dtype: datetime64[us]

# %%
df.isnull()
# Out:
#     Name    Age  Salary  bonus   Team    DOJ
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False   False  False  False  False

# %%
import numpy as np
df.loc[df.Name=='shivraj','Salary']=np.nan
df
# Out:
#       Name  Age   Salary    bonus Team        DOJ
# 0  krishna   16  90000.0  18000.0  CEO 2024-01-01
# 1  sarthak   17  70000.0  14000.0   HR 2024-02-15
# 2   ramraj   18  50000.0  10000.0  CTO 2024-03-10
# 3  shivraj   19      NaN   6000.0   DA 2024-04-20

# %%
df.isnull()
# Out:
#     Name    Age  Salary  bonus   Team    DOJ
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False    True  False  False  False

# %%
df.fillna(0)
# Out:
#       Name  Age   Salary    bonus Team        DOJ
# 0  krishna   16  90000.0  18000.0  CEO 2024-01-01
# 1  sarthak   17  70000.0  14000.0   HR 2024-02-15
# 2   ramraj   18  50000.0  10000.0  CTO 2024-03-10
# 3  shivraj   19      0.0   6000.0   DA 2024-04-20

# %%
df.loc[df.Name=='shivraj','Salary']=30000

# %%
# agresagtion and group by

# %%
df["Month"] = df["DOJ"].dt.month

# %%
df["Month"].value_counts()
# Out:
# Month
# 1    1
# 2    1
# 3    1
# 4    1
# Name: count, dtype: int64

# %%
df.groupby('Month')['Salary'].sum()
# Out:
# Month
# 1    90000.0
# 2    70000.0
# 3    50000.0
# 4    30000.0
# Name: Salary, dtype: float64
